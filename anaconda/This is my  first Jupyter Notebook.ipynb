# %%
print ("hello world")
# Out:
# hello world

# %%
"hello again"
# Out:
# 'hello again'

# %%
s = "hello again"

# %%
print (s)
# Out:
# hello again

# %%
l = [1, 2,3]

# %%
print(l)
# Out:
# [1, 2, 3]

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots()
axes.plot (l)

# %%
d = dict()
d["susan"] = 5
d["can"]=6
d["can1"]=2
print(d)
fig, axes = plt.subplots()
axes.plot (d.values())
# Out:
# {'susan': 5, 'can': 6, 'can1': 2}

# %%
for i in range (0, 5) :
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
